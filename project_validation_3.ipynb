# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
def leer_hoja(file, sheet_name):
    assert(sheet_name in {"Bodega_Puerto", "Bodega_Saladillo"})

    return pd.read_excel(file, index_col=0, header = 1, sheet_name=sheet_name)

def leer_excel(file):
    return leer_hoja(file, "Bodega_Saladillo"), leer_hoja(file, "Bodega_Puerto")

def to_series(df):
    return pd.concat([df.iloc[:, i] for i in range(df.shape[1])], keys = np.arange(df.shape[1]))

def series_df(df_list, col_names):
#     series = [to_series(df).values for df in df_list]
    series = [to_series(df) for df in df_list]
    
    out = pd.concat(series, axis=1)
#     out = pd.DataFrame({col_name: series[i] for i, col_name in enumerate(col_names)})
    out.columns = col_names
    return out

# %%
df_saladillo1, df_puerto1 = leer_excel("Semilla 1.xlsx")
df_saladillo2, df_puerto2 = leer_excel("Semilla2.xlsx")
df_saladillo6, df_puerto6 = leer_excel("Semilla 6.xlsx")

df_dia_saladillo, df_dia_puerto = leer_excel("MiDia.xlsx")
df_resultados_saladillo, df_resultados_puerto = leer_excel("ResultadosV8.xlsx")

# df_dia = pd.read_excel("MiDia.xlsx")
# df_resultados = pd.read_excel("ResultadosV8.xlsx")

# %%
df_saladillo1.head()
# Out:
# Index(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
#        'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30',
#        'Unnamed: 31', 'Unnamed: 32'],
#       dtype='object')
#           Unnamed: 1   Unnamed: 2  Unnamed: 3   Unnamed: 4   Unnamed: 5  \
# Hora
# 00:00:00    0.029775  1071.947584  643.180460  1071.947584  1071.947584
# 01:00:00    0.000000   680.509228  251.742104   680.509228   680.509228
# 02:00:00    0.000000   787.701008  358.933885   787.701008   787.701008
# 03:00:00    0.000000   894.892789  466.125666   894.892789   894.892789
# ...

# %%
df2.head()
# Out:
#    0.000000     1071.917808  643.150685   1071.917808  1071.917808  \
# 0          NaN     0.000000   680.479452   251.712329   680.479452
# 1          NaN     0.000000   787.671233   358.904110   787.671233
# 2          NaN     0.000000   894.863014   466.095890   894.863014
# 3          NaN     0.000000  1002.054795   573.287671  1002.054795
# 4          NaN    37.328767  1109.246575   680.479452  1109.246575
#
#    643.150685   1071.917808  1071.917808  1071.917808  643.150685   ...  \
# 0   680.479452   251.712329   680.479452   680.479452   680.479452  ...
# 1   787.671233   358.904110   787.671233   787.671233   787.671233  ...
# 2   894.863014   466.095890   894.863014   894.863014   894.863014  ...
# 3  1002.054795   573.287671  1002.054795  1002.054795  1002.054795  ...
# 4  1109.246575   680.479452  1109.246575  1109.246575  1109.246575  ...
#
#    2629.726026  1823.698629  1017.671231  1651.643834  3005.616437  \
# ...

# %%
df6.head()
# Out:
#         Dia         1            2            3            4           5  \
# 0      Hora       NaN          NaN          NaN          NaN         NaN
# 1  00:00:00  0.029775  1209.481830  1123.454433  1757.427036  951.399638
# 2  01:00:00  0.000000   818.043474   732.016077  1365.988680  559.961282
# 3  02:00:00  0.000000   925.235255   839.207858  1473.180460  667.153063
# 4  03:00:00  0.000000  1032.427036   946.399639  1580.372241  774.344844
#
#              6            7            8           9  ...           23  \
# 0          NaN          NaN          NaN         NaN  ...          NaN
# 1  1071.947584  2425.920186  1619.892789  813.865392  ...  3007.016076
# 2   680.509228  2034.481830  1228.454433  422.427036  ...  2615.577720
# 3   787.701008  2141.673611  1335.646214  529.618817  ...  2722.769501
# 4   894.892789  2248.865392  1442.837995  636.810598  ...  2829.961281
#
#             24           25           26           27           28  \
# ...

# %%
df_dia.head()
# Out:
#   Unnamed: 0         1            2           3            4            5  \
# 0       Hora       NaN          NaN         NaN          NaN          NaN
# 1   00:00:00  0.029775  1071.947584  643.180460  1071.947584  1071.947584
# 2   01:00:00  0.000000   680.509228  251.742104   680.509228   680.509228
# 3   02:00:00  0.000000   787.701008  358.933885   787.701008   787.701008
# 4   03:00:00  0.000000   894.892789  466.125666   894.892789   894.892789
#
#             6            7            8            9  ...           23  \
# 0         NaN          NaN          NaN          NaN  ...          NaN
# 1  643.180460  1071.947584  1071.947584  1071.947584  ...  3435.783199
# 2  251.742104   680.509228   680.509228   680.509228  ...  3044.344843
# 3  358.933885   787.701008   787.701008   787.701008  ...  3151.536624
# 4  466.125666   894.892789   894.892789   894.892789  ...  3258.728405
#
#             24           25           26           27           28  \
# ...

# %%
df_resultados.head()
# Out:
#   Semilla            1            2            3            4            5  \
# 0     Dia          NaN          NaN          NaN          NaN          NaN
# 1       1     0.000000     0.000000     0.000000     0.000000     0.000000
# 2       2  1071.947584  1209.481830  1209.481830  1071.947584  1071.947584
# 3       3   643.180460  1123.454433  1123.454433  1705.920186  1705.920186
# 4       4  1071.947584  1071.947584  1071.947584  2339.892789  2339.892789
#
#              6
# 0          NaN
# 1     0.000000
# 2  1209.481830
# 3  1123.454433
# 4  1757.427036

# %% [markdown]
# # data exploration

# %%
df_saladillo1.iloc[:, 6].plot()

# %%
saladillo_series = to_series(df_saladillo1)

# %%
saladillo_series.plot()

# %%
df_list = [df_saladillo1, df_puerto1, df_saladillo2, df_puerto2, df_saladillo6, df_puerto6]
name_list = ["saladillo1", "puerto1", "saladillo2", "puerto2", "saladillo6", "puerto6"]
df_series = series_df(df_list, name_list)

# %%
df_series.plot()
